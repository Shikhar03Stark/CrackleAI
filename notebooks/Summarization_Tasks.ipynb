# %%
# !pip install transformers sentencepiece
# Out:
# ...
#      |████████████████████████████████| 4.0 MB 5.4 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 39.0 MB/s
# ...
#      |████████████████████████████████| 880 kB 32.6 MB/s
# ...
#      |████████████████████████████████| 596 kB 44.2 MB/s
# ...
#      |████████████████████████████████| 77 kB 6.1 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 37.1 MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=2f4604fc1013cd941d8faa05ee60ed7f89fe381643b4bbb42a40591a94de2227
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built sacremoses
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

tokenizer = AutoTokenizer.from_pretrained("google/pegasus-wikihow")

model = AutoModelForSeq2SeqLM.from_pretrained("google/pegasus-wikihow")
# Out:
# Downloading:   0%|          | 0.00/87.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.09k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.82M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.12G [00:00<?, ?B/s]

# %%
summarizer = pipeline('summarization', model=model, tokenizer=tokenizer)

# %%
long_text = "The tower is 324 metres (1,063 ft) tall, about the same height as an 81-storey building, and the tallest structure in Paris. Its base is square, measuring 125 metres (410 ft) on each side. During its construction, the Eiffel Tower surpassed the Washington Monument to become the tallest man-made structure in the world, a title it held for 41 years until the Chrysler Building in New York City was finished in 1930. It was the first structure to reach a height of 300 metres. Due to the addition of a broadcasting aerial at the top of the tower in 1957, it is now taller than the Chrysler Building by 5.2 metres (17 ft). Excluding transmitters, the Eiffel Tower is the second tallest free-standing structure in France after the Millau Viaduct."

# %%
summ = summarizer(long_text)
summ
# Out:
# Your max_length is set to 256, but you input_length is only 158. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=79)
# [{'summary_text': 'The Eiffel Tower is the tallest structure in the world and the second tallest free-standing structure in France, built in the 19th and 20th centuries.'}]

# %%
summ[0]['summary_text']
# Out:
# 'The Eiffel Tower is the tallest structure in the world and the second tallest free-standing structure in France, built in the 19th and 20th centuries.'

# %% [markdown]
# Title Generation

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("Michau/t5-base-en-generate-headline")

model = AutoModelForSeq2SeqLM.from_pretrained("Michau/t5-base-en-generate-headline")
# Out:
# Downloading:   0%|          | 0.00/43.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.74k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]

# %%
title_generator = pipeline("text2text-generation", model=model, tokenizer=tokenizer)

# %%
title_generator("The Eiffel Tower is the tallest structure in the world and the second tallest free-standing structure in France, built in the 19th and 20th centuries.")
# Out:
# [{'generated_text': 'Eiffel Tower - The Tallest Structure in the World'}]
